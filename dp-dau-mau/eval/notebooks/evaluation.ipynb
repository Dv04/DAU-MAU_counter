# %% [markdown]
# # Evaluation Notebook
# This notebook demonstrates the DAU/MAU evaluation workflow. Run `python eval/evaluate.py` and `python eval/plots.py` first, then load figures from `{{DATA_DIR}}/plots/{{EXPERIMENT_ID}}/`.
